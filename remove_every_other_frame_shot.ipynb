# %%
import os, sys

# %%
# !ls
# Out:
# carsa.mp4				  pac3.mp4
# carsa_trim.mp4				  pac3_folder
# carsa_trim_folder			  pac3_folder_small
# load_csv_remove_skipped_files_test.ipynb  remove_every_other_frame.ipynb
# pac2.mp4				  remove_every_other_frame_shot.ipynb
# pac2_folder				  rename_files.ipynb
# pac2_folder_small			  vertical
# pac2_folder_small_half

# %%
directory = "pac3_folder_small_half"

# %%
# for dir_name in os.listdir(directory):
#     print(dir_name)
count = 0
for file_name in os.listdir(directory):
    file_path = os.path.join(directory, file_name)
#         print("\t" + file_path)
    if count % 2 == 1:
        print("Removed: {}".format(file_path))
        os.remove(file_path)

    count +=1
# Out:
# Removed: pac3_folder_small_half/pac3_10064.jpg
# Removed: pac3_folder_small_half/pac3_10066.jpg
# Removed: pac3_folder_small_half/pac3_10068.jpg
# Removed: pac3_folder_small_half/pac3_10070.jpg
# Removed: pac3_folder_small_half/pac3_10082.jpg
# Removed: pac3_folder_small_half/pac3_10084.jpg
# Removed: pac3_folder_small_half/pac3_10086.jpg
# Removed: pac3_folder_small_half/pac3_10088.jpg
# Removed: pac3_folder_small_half/pac3_10090.jpg
# Removed: pac3_folder_small_half/pac3_10092.jpg
# Removed: pac3_folder_small_half/pac3_10094.jpg
# Removed: pac3_folder_small_half/pac3_10096.jpg
# Removed: pac3_folder_small_half/pac3_10098.jpg
# Removed: pac3_folder_small_half/pac3_10106.jpg
# Removed: pac3_folder_small_half/pac3_10108.jpg
# Removed: pac3_folder_small_half/pac3_10110.jpg
# Removed: pac3_folder_small_half/pac3_10112.jpg
# Removed: pac3_folder_small_half/pac3_10114.jpg
# Removed: pac3_folder_small_half/pac3_10116.jpg
# Removed: pac3_folder_small_half/pac3_10118.jpg
# ...
